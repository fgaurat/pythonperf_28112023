# %%
import pandas as pd

from UserDAO import UserDAO

# %%
a=2

# %%
a
# Out:
# 2

# %%
dao = UserDAO('users_db.db')

# %%
# l = list(dao.findAll())
df_users = pd.DataFrame(dao.findAll())
#df_users

# %%
df_users.tail()
# Out:
#         id first_name  last_name                    email  gender  \
# 996    997    Garrott      Mewha    gmewharo@vkontakte.ru    Male
# 997    998   Patience       East        peastrp@blogs.com  Female
# 998    999     Godfry  Bernardin  gbernardinrq@meetup.com    Male
# 999   1000   Vivianna    Lubbock       vlubbockrr@msn.com  Female
# 1000  1001       Fred     GAURAT            fred@toto.com    Male
#
#           ip_address
# 996   210.27.104.228
# 997   124.227.43.198
# 998    23.147.18.118
# 999    23.50.118.123
# 1000

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1001 non-null   int64
#  1   first_name  1001 non-null   object
#  2   last_name   1001 non-null   object
#  3   email       1001 non-null   object
#  4   gender      1001 non-null   object
#  5   ip_address  1001 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ KB

# %%
df_users.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %%
df_users[['first_name','last_name']]
# Out:
#      first_name  last_name
# 0          Bary       Joan
# 1      Charissa  Crowcroft
# 2       Gusella     Ainger
# 3       Jacklyn     Jossum
# 4         Lanae   McGibbon
# ...         ...        ...
# 996     Garrott      Mewha
# 997    Patience       East
# 998      Godfry  Bernardin
# 999    Vivianna    Lubbock
# 1000       Fred     GAURAT
#
# [1001 rows x 2 columns]

# %%
df_users.iloc[996]
# Out:
# id                              997
# first_name                  Garrott
# last_name                     Mewha
# email         gmewharo@vkontakte.ru
# gender                         Male
# ip_address           210.27.104.228
# Name: 996, dtype: object

# %%
df_users[df_users['gender']=='Male']
# Out:
#         id first_name    last_name                         email gender  \
# 0        1       Bary         Joan          bjoan0@microsoft.com   Male
# 6        7     Pennie    MacNalley  pmacnalley6@seattletimes.com   Male
# 8        9     Hamnet  Harrowsmith    hharrowsmith8@hatena.ne.jp   Male
# 10      11    Bronson      Kensitt         bkensitta@example.com   Male
# 13      14    Cecilio      Kwietek         ckwietekd@tinyurl.com   Male
# ...    ...        ...          ...                           ...    ...
# 994    995        Ban       Izakov       bizakovrm@goodreads.com   Male
# 995    996   Fielding       Buttle         fbuttlern@smugmug.com   Male
# 996    997    Garrott        Mewha         gmewharo@vkontakte.ru   Male
# 998    999     Godfry    Bernardin       gbernardinrq@meetup.com   Male
# 1000  1001       Fred       GAURAT                 fred@toto.com   Male
#
#            ip_address
# 0     218.122.174.216
# 6        46.43.230.53
# 8      203.59.190.104
# ...

# %%
# df_users['upper_last_name'] = df_users['last_name'].map(lambda i:i.upper())
df_users['upper_last_name'] = df_users['last_name'].map(str.upper)

# %%
df_users
# Out:
#         id first_name  last_name                      email    gender  \
# 0        1       Bary       Joan       bjoan0@microsoft.com      Male
# 1        2   Charissa  Crowcroft   ccrowcroft1@examiner.com    Female
# 2        3    Gusella     Ainger  gainger2@reverbnation.com    Female
# 3        4    Jacklyn     Jossum   jjossum3@photobucket.com    Female
# 4        5      Lanae   McGibbon           lmcgibbon4@ow.ly  Bigender
# ...    ...        ...        ...                        ...       ...
# 996    997    Garrott      Mewha      gmewharo@vkontakte.ru      Male
# 997    998   Patience       East          peastrp@blogs.com    Female
# 998    999     Godfry  Bernardin    gbernardinrq@meetup.com      Male
# 999   1000   Vivianna    Lubbock         vlubbockrr@msn.com    Female
# 1000  1001       Fred     GAURAT              fred@toto.com      Male
#
#            ip_address upper_last_name
# 0     218.122.174.216            JOAN
# 1       102.53.205.20       CROWCROFT
# ...
